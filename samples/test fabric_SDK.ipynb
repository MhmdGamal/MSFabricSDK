# %%
# !pip install /lakehouse/default/Files/fabric_sdk-0.1.0-py3-none-any.whl
# Out:
# StatementMeta(, 85f359bd-f58c-46c6-8c91-a2eb1be748b0, 3, Finished, Available, Finished)
# Processing /lakehouse/default/Files/fabric_sdk-0.1.0-py3-none-any.whl
# ...

# %%
from fabric_sdk.api import FabricAPIBase

# Create an instance and use the methods
fabric_api = FabricAPIBase()
# Out:
# StatementMeta(, 85f359bd-f58c-46c6-8c91-a2eb1be748b0, 4, Finished, Available, Finished)

# %%
fabric_api.GetAllLakehouses()
# Out:
# StatementMeta(, 85f359bd-f58c-46c6-8c91-a2eb1be748b0, 5, Finished, Available, Finished)
#                                      Id               Display Name  \
# 0  47cfcd75-d361-4de0-8ab1-1897d120ec4c  DataflowsStagingLakehouse
# 1  62581562-429d-4f4f-a1cf-6247983d7742          sp_test_lakehouse
# 2  72115710-5c4d-4f1b-ae5a-7f2cfa1c4844                      genai
# 3  382dab8f-918b-4f2c-8f9b-ffe07f0758bb          SentimentAnalysis
# 4  bcec5c83-926d-44f2-bff3-ea82c668f76a            Sales_Lakehouse
# 5  237003a4-b283-476d-8d5e-cc59e747c221                   GenAI_DE
# 6  36141d52-fb97-46f2-8388-64b668258e40                 DEmoSample
# 7  aadf020e-2f0d-48e1-b674-b955a30abb99                    demo_01
# 8  dc12f3ba-da6e-41fa-bb59-25198a2af0cc                  hadi_demo
# 9  7872424b-b632-4446-95b9-4deba26c6af2                 test_FBSDK
#
#   Description       Type                          Workspace Id
# 0              Lakehouse  ef8ecf7d-15c4-46cd-b786-125579ab4857
# ...

# %%
fabric_api.GetFabricWorkspaces()
# Out:
# StatementMeta(, 85f359bd-f58c-46c6-8c91-a2eb1be748b0, 6, Finished, Available, Finished)
#                                      Id  Is Read Only  \
# 0  252baade-39dd-4012-8312-35b9941f7d5f         False
# 1  ef8ecf7d-15c4-46cd-b786-125579ab4857         False
#
#    Is On Dedicated Capacity                           Capacity Id  \
# 0                      True  7b9bd709-5866-4049-adb8-97388ed24120
# 1                      True  3d28dead-845c-4219-832d-ece0748f41f9
#
#   Default Dataset Storage Format       Type             Name  \
# 0                          Small  Workspace              Lab
# 1                          Small  Workspace  Fabric Demo-Dev
#
#                 Git_status
# 0             NotConnected
# 1  ConnectedAndInitialized

# %%
fabric_api.GetPowerBIWorkspaces()
# Out:
# StatementMeta(, 85f359bd-f58c-46c6-8c91-a2eb1be748b0, 7, Finished, Available, Finished)
#                                      Id  Is Read Only  \
# 2  fc9a40a2-9197-45ba-b4fa-b6e7dee85ce7         False
# 3  1e823130-5bd9-4f61-889e-1a27eb479aa0         False
# 4  22b44eb2-f3be-442c-80d3-2f9b6bff0d28         False
#
#    Is On Dedicated Capacity                           Capacity Id  \
# 2                     False                                   NaN
# 3                      True  78c4cbce-f584-4f12-a7a1-17d4852ecde4
# 4                      True  95dcedc6-e90d-4bf0-a28a-8fb9603265fc
#
#   Default Dataset Storage Format       Type         Name    Git_status
# 2                            NaN  Workspace      test_GL  NotConnected
# 3                          Large  Workspace  Fabric-Demo  NotConnected
# 4                          Small  Workspace     GAC-SSIS  NotConnected
